# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import pickle

from process_dataset import speech_features, text_features

# %%
with open('trained_models/stacker.pkl', 'rb') as f:
    stacker = pickle.load(f)
# Out:
# [05:00:01] WARNING: ../src/learner.cc:1040:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [05:00:01] WARNING: ../src/learner.cc:749: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.
# [05:00:01] WARNING: ../src/learner.cc:438:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [05:00:02] WARNING: ../src/learner.cc:1040:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [05:00:02] WARNING: ../src/learner.cc:749: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.
# [05:00:02] WARNING: ../src/learner.cc:438:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [05:00:02] WARNING: ../src/learner.cc:1040:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.
#
# [05:00:02] WARNING: ../src/learner.cc:749: Found JSON model saved before XGBoost 1.6, please save the model using current version again. The support for old JSON model will be discontinued in XGBoost 2.3.
# [05:00:02] WARNING: ../src/learner.cc:438:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.

# %%
x_train_s, x_test_s, y_train_s, y_test_s = speech_features.get_train_test()
x_train_t, x_test_t, y_train_t, y_test_t = text_features.get_train_test()

# %%
results = stacker.predict(x_test_s, x_test_t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/rafid/Documents/github/emotion-recognition-ensemble-learning/confusion_matrix.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/rafid/Documents/github/emotion-recognition-ensemble-learning/confusion_matrix.ipynb#ch0000003?line=0'>1</a> results = stacker.predict(x_test_s, x_test_t)
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/ensemble.py:261, in StackEnsemble.predict(self, x_speech, x_text, proba)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/ensemble.py?line=257'>258</a> meta_x = list()
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/ensemble.py?line=259'>260</a> for name, model in self.speech_models:
# --> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/ensemble.py?line=260'>261</a>     meta_x.append(model.predict_proba(x_speech))
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/ensemble.py?line=262'>263</a> for name, model in self.text_models:
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/ensemble.py?line=263'>264</a>     meta_x.append(model.predict_proba(x_text))
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py:1512, in XGBClassifier.predict_proba(self, X, ntree_limit, validate_features, base_margin, iteration_range)
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1503'>1504</a> if self.objective == "multi:softmax":
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1504'>1505</a>     # We need to run a Python implementation of softmax for it.  Just ask user to
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1505'>1506</a>     # use softprob since XGBoost's implementation has mitigation for floating
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1506'>1507</a>     # point overflow.  No need to reinvent the wheel.
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1507'>1508</a>     raise ValueError(
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1508'>1509</a>         "multi:softmax doesn't support `predict_proba`.  "
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1509'>1510</a>         "Switch to `multi:softproba` instead"
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1510'>1511</a>     )
# -> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1511'>1512</a> class_probs = super().predict(
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1512'>1513</a>     X=X,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1513'>1514</a>     ntree_limit=ntree_limit,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1514'>1515</a>     validate_features=validate_features,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1515'>1516</a>     base_margin=base_margin,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1516'>1517</a>     iteration_range=iteration_range
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1517'>1518</a> )
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1518'>1519</a> # If model is loaded from a raw booster there's no `n_classes_`
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1519'>1520</a> return _cls_predict_proba(getattr(self, "n_classes_", 0), class_probs, np.vstack)
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py:1047, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1042'>1043</a> iteration_range = _convert_ntree_limit(
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1043'>1044</a>     self.get_booster(), ntree_limit, iteration_range
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1044'>1045</a> )
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1045'>1046</a> iteration_range = self._get_iteration_range(iteration_range)
# -> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1046'>1047</a> if self._can_use_inplace_predict():
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1047'>1048</a>     try:
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1048'>1049</a>         predts = self.get_booster().inplace_predict(
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1049'>1050</a>             data=X,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1050'>1051</a>             iteration_range=iteration_range,
#    (...)
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1054'>1055</a>             validate_features=validate_features,
#    <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=1055'>1056</a>         )
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py:983, in XGBModel._can_use_inplace_predict(self)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=977'>978</a> def _can_use_inplace_predict(self) -> bool:
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=978'>979</a>     # When predictor is explicitly set, using `inplace_predict` might result into
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=979'>980</a>     # error with incompatible data type.
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=980'>981</a>     # Inplace predict doesn't handle as many data types as DMatrix, but it's
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=981'>982</a>     # sufficient for dask interface where input is simpiler.
# --> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=982'>983</a>     predictor = self.get_params().get("predictor", None)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=983'>984</a>     if predictor in ("auto", None) and self.booster != "gblinear":
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=984'>985</a>         return True
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py:636, in XGBModel.get_params(self, deep)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=633'>634</a> cp = copy.copy(self)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=634'>635</a> cp.__class__ = cp.__class__.__bases__[0]
# --> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=635'>636</a> params.update(cp.__class__.get_params(cp, deep))
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=636'>637</a> # if kwargs is a dict, update params accordingly
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=637'>638</a> if hasattr(self, "kwargs") and isinstance(self.kwargs, dict):
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py:633, in XGBModel.get_params(self, deep)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=625'>626</a> """Get parameters."""
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=626'>627</a> # Based on: https://stackoverflow.com/questions/59248211
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=627'>628</a> # The basic flow in `get_params` is:
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=628'>629</a> # 0. Return parameters in subclass first, by using inspect.
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=629'>630</a> # 1. Return parameters in `XGBModel` (the base class).
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=630'>631</a> # 2. Return whatever in `**kwargs`.
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=631'>632</a> # 3. Merge them.
# --> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=632'>633</a> params = super().get_params(deep)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=633'>634</a> cp = copy.copy(self)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/xgboost/sklearn.py?line=634'>635</a> cp.__class__ = cp.__class__.__bases__[0]
#
# File ~/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py:210, in BaseEstimator.get_params(self, deep)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py?line=207'>208</a> out = dict()
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py?line=208'>209</a> for key in self._get_param_names():
# --> <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py?line=209'>210</a>     value = getattr(self, key)
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py?line=210'>211</a>     if deep and hasattr(value, "get_params"):
#     <a href='file:///home/rafid/Documents/github/emotion-recognition-ensemble-learning/env/lib/python3.8/site-packages/sklearn/base.py?line=211'>212</a>         deep_items = value.get_params().items()
#
# AttributeError: 'XGBModel' object has no attribute 'callbacks'

# %%
categories = ['ang', 'hap', 'neu', 'sad']
cf_matrix = confusion_matrix(y_test_s, results, labels=categories)

sns.heatmap(cf_matrix, annot=True, xticklabels = categories, yticklabels = categories, cmap='Greens', fmt="d")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
